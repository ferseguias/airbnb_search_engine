# %%
import pandas as pd
import geopandas as gpd
import sidetable
pd.options.display.max_columns = None

# %%
apartments = pd.read_csv('/Users/fernandoseguias/Desktop/ferseg/Proyectos/Programacion/iron_hack/project_2/data/listings_detailed.csv')

apartments_filtered = apartments.loc[:,['id', 'listing_url', 'picture_url', 'name', 'description', 'host_id', 
                    'host_since', 'host_is_superhost', 'neighbourhood_cleansed', 
                    'neighbourhood_group_cleansed', 'latitude', 'longitude', 'room_type', 
                    'accommodates', 'price', 'availability_365', 'number_of_reviews', 'review_scores_rating']]

# %%
apartments_filtered.sample(5)
# Out:
#              id                            listing_url  \
# 4431   19437974  https://www.airbnb.com/rooms/19437974
# 14683  48928504  https://www.airbnb.com/rooms/48928504
# 13054  43751236  https://www.airbnb.com/rooms/43751236
# 3346   16450507  https://www.airbnb.com/rooms/16450507
# 10555  36823891  https://www.airbnb.com/rooms/36823891
#
#                                              picture_url  \
# 4431   https://a0.muscache.com/pictures/cbeef2dd-fbe0...
# 14683  https://a0.muscache.com/pictures/prohost-api/H...
# 13054  https://a0.muscache.com/pictures/912e39f1-bf6e...
# 3346   https://a0.muscache.com/pictures/8cd44b08-2ca1...
# 10555  https://a0.muscache.com/pictures/7ff9fb4f-85a9...
#
#                                                    name  \
# 4431              Piso señorial en el corazón de Chueca
# 14683                         Redondilla - Palacio Real
# 13054                   Unico y acogedor piso en Madrid
# 3346                  Central and comfortable apartment
# 10555  Habitación en Delicias, Mad. Calefacción central
#
#                                              description    host_id  \
# 4431   Magnifico piso de lujo, con techos originales ...    7825042
# 14683  It is a loft for seven people with four bedroo...   28038703
# 13054  Piso acogedor ubicado en pleno corazón de la c...   85307625
# 3346   Places of interest: Reina Sofía, Prado, Thysse...   59187172
# 10555  El piso se encuentra acondicionado con todo lo...  242684722
#
#        host_since host_is_superhost neighbourhood_cleansed  \
# 4431   2013-07-30                 f               Justicia
# 14683  2015-02-20                 f                Palacio
# 13054  2016-07-22                 f                Acacias
# 3346   2016-02-17                 f            Embajadores
# 10555  2019-02-12                 t                Chopera
#
#       neighbourhood_group_cleansed  latitude  longitude        room_type  \
# 4431                        Centro  40.42193   -3.69712  Entire home/apt
# 14683                       Centro  40.41137   -3.71190  Entire home/apt
# 13054                   Arganzuela  40.40321   -3.70164  Entire home/apt
# 3346                        Centro  40.40976   -3.69693  Entire home/apt
# 10555                   Arganzuela  40.39430   -3.69853     Private room
#
#        accommodates    price  availability_365  number_of_reviews  \
# 4431              5  $180.00               191                  3
# 14683             7  $300.00                79                  1
# 13054             3   $48.00               125                 16
# 3346              3   $56.00                 0                252
# 10555             1   $16.00                 0                  7
#
#        review_scores_rating
# 4431                   5.00
# 14683                  5.00
# 13054                  4.63
# 3346                   4.71
# 10555                  4.43

# %%
apartments.loc[apartments['id'] == 52168533]
# Out:
#              id                            listing_url       scrape_id  \
# 16443  52168533  https://www.airbnb.com/rooms/52168533  20211208225122
#
#       last_scraped                                               name  \
# 16443   2021-12-09  Piso en Entrevías con 3 dormitorios y camas do...
#
#                                              description  \
# 16443  Disfruta de la comodidad de este alojamiento y...
#
#                                neighborhood_overview  \
# 16443  Zona de Entrevias, junto a Puente de Vallecas
#
#                                              picture_url   host_id  \
# 16443  https://a0.muscache.com/pictures/miso/Hosting-...  53449786
#
#                                          host_url        host_name  \
# 16443  https://www.airbnb.com/users/show/53449786  Maria Esperanza
#
#        host_since                       host_location host_about  \
# 16443  2016-01-05  Madrid, Community of Madrid, Spain        NaN
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 16443     within an hour               100%                  77%
#
#       host_is_superhost                                 host_thumbnail_url  \
# 16443                 f  https://a0.muscache.com/im/pictures/user/60d2c...
#
#                                         host_picture_url host_neighbourhood  \
# 16443  https://a0.muscache.com/im/pictures/user/60d2c...                NaN
#
#        host_listings_count  host_total_listings_count  \
# 16443                  2.0                        2.0
#
#                    host_verifications host_has_profile_pic  \
# 16443  ['email', 'phone', 'facebook']                    t
#
#       host_identity_verified                       neighbourhood  \
# 16443                      t  Madrid, Comunidad de Madrid, Spain
#
#       neighbourhood_cleansed neighbourhood_group_cleansed  latitude  \
# 16443              Entrevías           Puente de Vallecas   40.3843
#
#        longitude       property_type        room_type  accommodates  \
# 16443  -3.671701  Entire rental unit  Entire home/apt             6
#
#        bathrooms bathrooms_text  bedrooms  beds                    amenities  \
# 16443        NaN         1 bath       3.0   3.0  ["Long term stays allowed"]
#
#         price  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 16443  $67.00              10             365                    10.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 16443                    10.0                   365.0                   365.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 16443                    10.0                   365.0               NaN
#
#       has_availability  availability_30  availability_60  availability_90  \
# 16443                t                0               28               58
#
#        availability_365 calendar_last_scraped  number_of_reviews  \
# 16443                58            2021-12-09                  1
#
#        number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 16443                      1                       0   2021-09-28  2021-09-28
#
#        review_scores_rating  review_scores_accuracy  \
# 16443                   2.0                     2.0
#
#        review_scores_cleanliness  review_scores_checkin  \
# 16443                        2.0                    5.0
#
#        review_scores_communication  review_scores_location  \
# 16443                          5.0                     4.0
#
#        review_scores_value license instant_bookable  \
# 16443                  2.0     NaN                f
#
#        calculated_host_listings_count  \
# 16443                               8
#
#        calculated_host_listings_count_entire_homes  \
# 16443                                            8
#
#        calculated_host_listings_count_private_rooms  \
# 16443                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 16443                                            0               0.41
